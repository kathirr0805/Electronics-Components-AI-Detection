# %%
pip install tensorflow

# %%
import tensorflow as tf
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from sklearn.model_selection import train_test_split
import os
import shutil

# %%
print(f"Source path: {os.path.join(class_path, image)}")
print(f"Destination path: {os.path.join(train_dir, class_name, image)}")
# Out:
# Source path: F:/Projects/AI/Electro AI/Datasets/archive/images\images\heat-sink
# Destination path: F:/Projects/AI/Electro AI/Datasets/archive/train\images\heat-sink

# %%
import os

for class_name in class_names:
    class_train_dir = os.path.join(train_dir, class_name)
    class_validation_dir = os.path.join(validation_dir, class_name)
    
    # Ensure these directories exist
    os.makedirs(class_train_dir, exist_ok=True)
    os.makedirs(class_validation_dir, exist_ok=True)

# %%
print(f"Class directory: {class_path}")
print(f"Images: {images}")
# Out:
# Class directory: F:/Projects/AI/Electro AI/Datasets/archive/images\images
# Images: []

# %%
images = [f for f in os.listdir(class_path) if os.path.isfile(os.path.join(class_path, f))]
print(f"Number of images in {class_name}: {len(images)}")
# Out:
# Number of images in transistor: 153

# %%
images = [f for f in os.listdir(class_path) if os.path.isfile(os.path.join(class_path, f))]
print(f"Number of images in {class_name}: {len(images)}")
# Out:
# Number of images in transistor: 153

# %%
for class_name in class_names:
    class_path = os.path.join(dataset_dir, class_name)
    images = [f for f in os.listdir(class_path) if os.path.isfile(os.path.join(class_path, f))]
    
    if not images:
        print(f"No images found in {class_path}, skipping.")
        continue

    train_images, validation_images = train_test_split(images, test_size=0.2, random_state=42)
    
    class_train_dir = os.path.join(train_dir, class_name)
    class_validation_dir = os.path.join(validation_dir, class_name)
    
    os.makedirs(class_train_dir, exist_ok=True)
    os.makedirs(class_validation_dir, exist_ok=True)
    
    for image in train_images:
        src = os.path.join(class_path, image)
        dst = os.path.join(class_train_dir, image)
        try:
            shutil.copy(src, dst)
        except Exception as e:
            print(f"Error copying {src} to {dst}: {e}")
    
    for image in validation_images:
        src = os.path.join(class_path, image)
        dst = os.path.join(class_validation_dir, image)
        try:
            shutil.copy(src, dst)
        except Exception as e:
            print(f"Error copying {src} to {dst}: {e}")
# Out:
# No images found in F:/Projects/AI/Electro AI/Datasets/archive/images\images, skipping.

# %%
import os

dataset_dir = 'F:/Projects/AI/Electro AI/Datasets/archive/images'
print(f"Dataset directory: {dataset_dir}")

# List all directories in dataset_dir
for item in os.listdir(dataset_dir):
    item_path = os.path.join(dataset_dir, item)
    if os.path.isdir(item_path):
        print(f"Class directory: {item_path}")
        print(f"Files in class directory: {os.listdir(item_path)}")
    else:
        print(f"Non-directory item: {item_path}")
# Out:
# Dataset directory: F:/Projects/AI/Electro AI/Datasets/archive/images
# Class directory: F:/Projects/AI/Electro AI/Datasets/archive/images\armature
# Files in class directory: ['armature-coil001.jpg', 'armature-coil002.jpg', 'armature-coil003.jpg', 'armature-coil004.jpg', 'armature-coil005.jpg', 'armature-coil006.jpg', 'armature-coil007.jpg', 'armature-coil008.jpg', 'armature-coil009.jpg', 'armature-coil010.jpg', 'armature-coil011.jpg', 'armature-coil012.jpg', 'armature-coil013.jpg', 'armature-coil014.jpg', 'armature-coil015.jpg', 'armature-coil016.jpg', 'armature-coil017.jpg', 'armature-coil018.jpg', 'armature-coil019.jpg', 'armature-coil020.jpg', 'armature-coil021.jpg', 'armature-coil022.jpg', 'armature-coil023.jpg', 'armature-coil024.jpg', 'armature-coil025.jpg', 'armature-coil026.jpg', 'armature-coil027.jpg', 'armature-coil028.jpg', 'armature-coil029.jpg', 'armature-coil030.jpg', 'armature-coil031.jpg
Bypass-capacitor036.jpg', 'Bypass-capacitor037.jpg', 'Bypass-capacitor038.jpg', 'Bypass-capacitor039.jpg', 'Bypass-capacitor040.jpg', 'Bypass-capacitor041.jpg', 'Bypass-capacitor042.jpg', 'Bypass-capacitor043.jpg', 'Bypass-capacitor044.jpg', 'Bypass-capacitor045.jpg', 'Bypass-capacitor046.jpg', 'Bypass-capacitor047.jpg', 'Bypass-capacitor048.jpg', 'Bypass-capacitor049.jpg', 'Bypass-capacitor050.jpg', 'Bypass-capacitor051.jpg', 'Bypass-capacitor052.jpg', 'Bypass-capacitor053.jpg', 'Bypass-capacitor054.jpg', 'Bypass-capacitor055.jpg', 'Bypass-capacitor056.jpg', 'Bypass-capacitor057.jpg', 'Bypass-capacitor058.jpg', 'Bypass-capacitor059.jpg', 'Bypass-capacitor060.jpg', 'Bypass-capacitor061.jpg', 'Bypass-capacitor062.jpg', 'Bypass-capacitor063.jpg', 'Bypass-capacitor064.jpg', 'Bypass-capacitor065.jpg', 'Bypass-capacitor066.jpg', 'Bypass-capacitor067.jpg', 'Bypass-capacitor068.jpg', 'Bypass-capacitor069.jpg', 'Bypass-capacitor070.jpg', 'Bypass-capacitor071.jpg', 'Bypass-capacitor072.jpg', 'Bypass-capacitor073.jpg', 'Bypass-capacitor074.jpg', 'Bypass-capacitor075.jpg', 'Bypass-capacitor076.jpg', 'Bypass-capacitor077.jpg', 'Bypass-capacitor078.jpg', 'Bypass-capacitor079.jpg', 'Bypass-capacitor080.jpg', 'Bypass-capacitor081.jpg', 'Bypass-capacitor082.jpg', 'Bypass-capacitor083.jpg', 'Bypass-capacitor084.jpg', 'Bypass-capacitor085.jpg', 'Bypass-capacitor086.jpg', 'Bypass-capacitor087.jpg', 'Bypass-capacitor088.jpg', 'Bypass-capacitor089.jpg', 'Bypass-capacitor090.jpg', 'Bypass-capacitor091.jpg', 'Bypass-capacitor092.jpg', 'Bypass-capacitor093.jpg', 'Bypass-capacitor094.jpg', 'Bypass-capacitor095.jpg', 'Bypass-capacitor096.jpg', 'Bypass-capacitor097.jpg', 'Bypass-capacitor098.jpg', 'Bypass-capacitor099.jpg', 'Bypass-capacitor100.jpg', 'Bypass-capacitor101.jpg', 'Bypass-capacitor102.jpg', 'Bypass-capacitor103.jpg', 'Bypass-capacitor104.jpg', 'Bypass-capacitor105.jpg', 'Bypass-capacitor106.jpg', 'Bypass-capacitor107.jpg', 'Bypass-capacitor108.jpg', 'Bypass-capacitor109.jpg', 'Bypass-capacitor110.jpg', 'Bypass-capacitor111.jpg', 'Bypass-capacitor112.jpg', 'Bypass-capacitor113.jpg', 'Bypass-capacitor114.jpg', 'Bypass-capacitor115.jpg', 'Bypass-capacitor116.jpg', 'Bypass-capacitor117.jpg', 'Bypass-capacitor118.jpg', 'Bypass-capacitor119.jpg', 'Bypass-capacitor120.jpg', 'Bypass-capacitor121.jpg', 'Bypass-capacitor122.jpg', 'Bypass-capacitor123.jpg', 'Bypass-capacitor124.jpg', 'Bypass-capacitor125.jpg', 'Bypass-capacitor126.jpg', 'Bypass
clip-lead133.jpg', 'clip-lead134.jpg', 'clip-lead135.jpg', 'clip-lead136.jpg', 'clip-lead137.jpg', 'clip-lead138.jpg', 'clip-lead139.jpg', 'clip-lead140.jpg', 'clip-lead141.jpg', 'clip-lead142.jpg', 'clip-lead143.jpg', 'clip-lead144.jpg', 'clip-lead145.jpg', 'clip-lead146.jpg', 'clip-lead147.jpg', 'clip-lead148.jpg', 'clip-lead149.jpg', 'clip-lead150.jpg', 'clip-lead151.jpg', 'clip-lead152.jpg', 'clip-lead153.jpg', 'clip-lead154.jpg', 'clip-lead155.jpg', 'clip-lead156.jpg', 'clip-lead157.jpg', 'clip-lead158.jpg', 'clip-lead159.jpg', 'clip-lead160.jpg', 'clip-lead161.jpg', 'clip-lead162.jpg', 'clip-lead163.jpg', 'clip-lead164.jpg', 'clip-lead165.jpg', 'clip-lead166.jpg', 'clip-lead167.jpg', 'clip-lead168.jpg', 'clip-lead169.jpg', 'clip-lead170.jpg', 'clip-lead171.jpg', 'clip-lead172.jpg', 'clip-lead173.jpg', 'clip-lead174.jpg', 'clip-lead175.jpg', 'clip-lead176.jpg', 'clip-lead177.jpg', 'clip-lead178.jpg', 'clip-lead179.jpg', 'clip-lead180.jpg', 'clip-lead181.jpg', 'clip-lead182.jpg', 'clip-lead183.jpg', 'clip-lead184.jpg', 'clip-lead185.jpg', 'clip-lead186.jpg', 'clip-lead187.jpg', 'clip-lead188.jpg', 'clip-lead189.jpg', 'clip-lead190.jpg', 'clip-lead191.jpg', 'clip-lead192.jpg', 'clip-lead193.jpg', 'clip-lead194.jpg', 'clip-lead195.jpg', 'clip-lead196.jpg', 'clip-lead197.jpg', 'clip-lead198.jpg', 'clip-lead199 ...
# Class directory: F:/Projects/AI/Electro AI/Datasets/archive/images\electric-relay
# Files in class directory: ['electric-relay001.jpg', 'electric-relay002.jpg', 'electric-relay003.jpg', 'electric-relay004.jpg', 'electric-relay005.jpg', 'electric-relay006.jpg', 'electric-relay007.jpg', 'electric-relay008.jpg', 'electric-relay009.jpg', 'electric-relay010.jpg', 'electric-relay011.jpg', 'electric-relay012.jpg', 'electric-relay013.jpg', 'electric-relay014.jpg', 'electric-relay015.jpg', 'electric-relay016.jpg', 'electric-relay017.jpg', 'electric-relay018.jpg', 'electric-relay019.jpg', 'electric-relay020.jpg', 'electric-relay021.jpg', 'electric-relay022.jpg', 'electric-relay023.jpg', 'electric-relay024.jpg', 'electric-relay025.jpg', 'electric-relay026.jpg', 'electric-relay027.jpg', 'electric-relay028.jpg', 'electric-relay029.jpg', 'electric-relay030.jpg', 'electric-relay091.jpg', 'electric-relay092.jpg', 'electric-relay093.jpg', 'electric-relay094.jpg', 'electric-relay095.jpg', 'electric-relay096.jpg', 'electric-relay097.jpg', 'electric-relay098.jpg', 'electric-relay099.jpg', 'electric-relay100.jpg', 'electric-relay101.jpg', 'electric-relay102.jpg', 'electric-relay103.jpg', 'electric-relay104.jpg', 'electric-relay105.jpg', 'electric-relay106.jpg', 'electric-relay107.jpg', 'electric-relay108.jpg', 'electric-relay109.jpg', 'electric-relay110.jpg', 'electric-relay111.jpg', 'electric-relay
# Class directory: F:/Projects/AI/Electro AI/Datasets/archive/images\Integrated-micro-circuit
# Files in class directory: ['Integrated-micro-circuit001.jpg', 'Integrated-micro-circuit002.jpg', 'Integrated-micro-circuit003.jpg', 'Integrated-micro-circuit004.jpg', 'Integrated-micro-circuit005.jpg', 'Integrated-micro-circuit006.jpg', 'Integrated-micro-circuit007.jpg', 'Integrated-micro-circuit008.jpg', 'Integrated-micro-circuit009.jpg', 'Integrated-micro-circuit010.jpg', 'Integrated-micro-circuit011.jpg', 'Integrated-micro-circuit012.jpg', 'Integrated-micro-circuit013.jpg', 'Integrated-micro-circuit014.jpg', 'Integrated-micro-circuit015.jpg', 'Integrated-micro-circuit016.jpg', 'Integrated-micro-circuit017.jpg', 'Integrated-micro-circuit018.jpg', 'Integrated-micro-circuit019.jpg', 'Integrated-micro-circuit020.jpg', 'Integrated-micro-circuit1000.jpg', 'Integrated-micro-circuit1001.jpg', 'Integrated-micro-circuit1002.jpg', 'Integrated-micro-circuit1003.jpg', 'Integrated-micro-circuit1004.jpg', 'Integrated-micro-circuit1005.jpg', 'Integrated-micro-circuit1006.jpg', 'Integrated-micro-circuit1007.jpg', 'Integrated-micro-circuit1008.jpg', 'Integrated-micro-circuit1009.jpg', 'Integrated-micro-circuit1010.jpg', 'Integrated-micro-circuit1011.jpg', 'Integrated-micro-circuit1012.jpg', 'Integrated-micro-circuit1013.jpg', 'Integrated-micro-circuit1014.jpg', 'Integrated-micro-circuit1015.jpg', 'Integrated-micro-circuit1016.jpg', 'Integrated-micro-circuit1017.jpg', 'Integrated-micro-circuit1018.jpg', 'Integrated-micro-circuit1019.jpg', 'Integrated-micro-circuit1020.jpg', 'Integrated-micro-circuit1021.jpg', 'Integrated-micro-circuit1022.jpg', 'Integrated-micro-circuit1023.jpg', 'Integrated-micro-circuit1024.jpg', 'Integrated-micro-circuit1025.jpg', 'Integrated-micro-circuit1026.jpg', 'Integrated-micro-circuit1027.jpg', 'Integrated-micro-circuit1028.jpg', 'Integrated-micro-circuit1029.jpg', 'Integrated-micro-circuit1030.jpg', 'Integrated-micro-circuit1101.jpg', 'Integrated-micro-circuit1102.jpg', 'Integrated-micro-circuit1103.jpg', 'Integrated-micro-circuit1104.jpg', 'Integrated-micro-circuit1105.jpg', 'Integrated-micro-circuit1106.jpg', 'Integrated-micro-circuit1107.jpg', 'Integrated-micro-circuit1108.jpg', 'Integrated-micro-circuit1109.jpg', 'Integrated-micro-circuit1110.jpg', 'Integrated-micro-circuit1111.jpg', 'Integrated-micro-circuit1112.jpg', 'Integrated-micro-circuit1113.jpg', 'Integrated-micro-circuit1114.jpg', 'Integrated-micro-circuit1115.jpg', 'Integrated-micro-circuit1116.jpg', 'Integrated-micro-circuit1117.jpg', 'Integrated-micro-circuit1118.jpg', 'Integrated-micro-circuit1119.jpg', 'Integrated-micro-circuit1120.jpg', 'Integrated-micro-circuit1121.jpg', 'Integrated-micro-circuit1122.jpg', 'Integrated-micro-circuit1123.jpg', 'Integrated-micro-circuit1124.jpg', 'Integrated-micro-circuit1125.jpg', 'Integrated-micro-circuit1126.jpg', 'Integrated-micro-circuit1127.jpg', 'Integrated-micro-circuit1128.jpg', 'Integrated-micro-circuit1129.jpg', 'Integrated-micro-circuit1130.jpg', 'Integrated-micro-circuit1191.jpg', '
', 'step-down-transformer026.jpg', 'step-down-transformer027.jpg', 'step-down-transformer028.jpg', 'step-down-transformer029.jpg', 'step-down-transformer030.jpg', 'step-down-transformer031.jpg', 'step-down-transformer032.jpg', 'step-down-transformer033.jpg', 'step-down-transformer034.jpg', 'step-down-transformer035.jpg', 'step-down-transformer036.jpg', 'step-down-transformer037.jpg', 'step-down-transformer038.jpg', 'step-down-transformer039.jpg', 'step-down-transformer040.jpg', 'step-down-transformer041.jpg', 'step-down-transformer042.jpg', 'step-down-transformer043.jpg', 'step-down-transformer044.jpg', 'step-down-transformer045.jpg', 'step-down-transformer046.jpg', 'step-down-transformer047.jpg', 'step-down-transformer048.jpg', 'step-down-transformer049.jpg', 'step-down-transformer050.jpg', 'step-down-transformer051.jpg', 'step-down-transformer052.jpg', 'step-down-transformer053.jpg', 'step-down-transformer054.jpg', 'step-down-transformer055.jpg', 'step-down-transformer056.jpg', 'step-down-transformer057.jpg', 'step-down-transformer058.jpg', 'step-down-transformer059.jpg', 'step-down-transformer060.jpg', 'step-down-transformer061.jpg', 'step-down-transformer062.jpg', 'step-down-transformer063.jpg', 'step-down-transformer064.jpg', 'step-down-transformer065.jpg', 'step-down-transformer066.jpg', 'step-down-transformer067.jpg', 'step-down-transformer068.jpg', 'step-down-transformer069.jpg', 'step-down-transformer070.jpg', 'step-down-transformer071.jpg', 'step-down-transformer072.jpg', 'step-down-transformer073.jpg', 'step-down-transformer074.jpg', 'step-down-transformer075.jpg', 'step-down-transformer076.jpg', 'step-down-transformer077.jpg', 'step-down-transformer078.jpg', 'step-down-transformer079.jpg', 'step-down-transformer080.jpg', 'step-down-transformer081.jpg', 'step-down-transformer082.jpg', 'step-down-transformer083.jpg', 'step-down-transformer084.jpg', 'step-down-transformer085.jpg', 'step-down-transformer086.jpg', 'step-down-transformer087.jpg', 'step-down-transformer088.jpg', 'step-down-transformer089.jpg', 'step-down-transformer090.jpg', 'step-down-transformer091.jpg', 'step-down-transformer092.jpg', 'step-down-transformer093.jpg', 'step-down-transformer094.jpg', 'step-down-transformer095.jpg', 'step-down-transformer096.jpg', 'step-down-transformer097.jpg', 'step-down-transformer098.jpg', 'step-down-transformer099.jpg', 'step-down-transformer100.jpg', 'step-down-transformer101.jpg', 'step-down-transformer102.jpg', 'step-down-transformer103.jpg', 'step-down-transformer104.jpg', 'step-down-transformer105.jpg', 'step-down-transformer106.jpg', 'step-down-transformer107.jpg', 'step-down-transformer108.jpg', 'step-down-transformer109.jpg', 'step-down-transformer110.jpg', 'step-down-transformer131.jpg', 'step-down-transformer132.jpg', 'step-down-transformer133.jpg', 'step-down-transformer134.jpg', 'step-down-transformer135.jpg', 'step-down-transformer136.jpg', 'step-down-transformer137.jpg', 'step-down-transformer138.jpg', 'step-down-transformer139.jpg', 'step-down-transformer140.jpg', 'step-down-transformer141.jpg', 'step-down-transformer142.jpg', 'step-down-transformer143.jpg', 'step-down-transformer144.jpg', 'step ...
# Class directory: F:/Projects/AI/Electro AI/Datasets/archive/images
for f in os.listdir(class_path) if os.path.isfile(os.path.join(class_path, f))]
    
    if not images:
        print(f"No images found in {class_path}, skipping.")
        continue

    train_images, validation_images = train_test_split(images, test_size=0.2, random_state=42)
    
    class_train_dir = os.path.join(train_dir, class_name)
    class_validation_dir = os.path.join(validation_dir, class_name)
    
    os.makedirs(class_train_dir, exist_ok=True)
    os.makedirs(class_validation_dir, exist_ok=True)
    
    for image in train_images:
        src = os.path.join(class_path, image)
        dst = os.path.join(class_train_dir, image)
        try:
            shutil.copy(src, dst)
        except Exception as e:
            print(f"Error copying {src} to {dst}: {e}")
    
    for image in validation_images:
        src = os.path.join(class_path, image)
        dst = os.path.join(class_validation_dir, image)
        try:
            shutil.copy(src, dst)
        except Exception as e:
            print(f"Error copying {src} to {dst}: {e}")
# Out:
# Class names: ['armature', 'attenuator', 'Bypass-capacitor', 'cartridge-fuse', 'clip-lead', 'electric-relay', 'Electrolytic-capacitor', 'filament', 'heat-sink', 'images', 'induction-coil', 'Integrated-micro-circuit', 'jumper-cable', 'junction-transistor', 'LED', 'light-circuit', 'limiter-clipper', 'local-oscillator', 'memory-chip', 'microchip', 'microprocessor', 'multiplexer', 'omni-directional-antenna', 'PNP-transistor', 'potential-divider', 'potentiometer', 'pulse-generator', 'relay', 'rheostat', 'semi-conductor', 'semiconductor-diode', 'shunt', 'solenoid', 'stabilizer', 'step-down-transformer', 'step-up-transformer', 'transistor']
# No images found in F:/Projects/AI/Electro AI/Datasets/archive/images\images, skipping.

# %%
from tensorflow.keras.preprocessing.image import ImageDataGenerator

# Set up data generators
train_datagen = ImageDataGenerator(rescale=1./255)
validation_datagen = ImageDataGenerator(rescale=1./255)

train_generator = train_datagen.flow_from_directory(
    train_dir,
    target_size=(150, 150),
    batch_size=20,
    class_mode='sparse')

validation_generator = validation_datagen.flow_from_directory(
    validation_dir,
    target_size=(150, 150),
    batch_size=20,
    class_mode='sparse')

# Define your model architecture
model = tf.keras.models.Sequential([
    tf.keras.layers.Conv2D(32, (3, 3), activation='relu', input_shape=(150, 150, 3)),
    tf.keras.layers.MaxPooling2D((2, 2)),
    tf.keras.layers.Flatten(),
    tf.keras.layers.Dense(64, activation='relu'),
    tf.keras.layers.Dense(len(train_generator.class_indices), activation='softmax')  # Adjust the number of classes
])

# Compile the model
model.compile(optimizer='adam',
              loss='sparse_categorical_crossentropy',
              metrics=['accuracy'])

# Train the model
history = model.fit(
    train_generator,
    steps_per_epoch=train_generator.samples // train_generator.batch_size,
    epochs=10,
    validation_data=validation_generator,
    validation_steps=validation_generator.samples // validation_generator.batch_size)

# Save the model
model_path = os.path.join(dataset_dir, 'model.h5')
model.save(model_path)
print(f"Model saved to {model_path}")
# Out:
# Found 8777 images belonging to 39 classes.
# Found 2213 images belonging to 39 classes.
# Epoch 1/10
# S:\itzka\anaconda3\Lib\site-packages\keras\src\layers\convolutional\base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# S:\itzka\anaconda3\Lib\site-packages\keras\src\trainers\data_adapters\py_dataset_adapter.py:122: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# 438/438 ━━━━━━━━━━━━━━━━━━━━ 43s 95ms/step - accuracy: 0.0618 - loss: 4.2434 - val_accuracy: 0.0709 - val_loss: 3.5145
# Epoch 2/10
# 438/438 ━━━━━━━━━━━━━━━━━━━━ 0s 158us/step - accuracy: 0.0500 - loss: 3.6512 - val_accuracy: 0.0000e+00 - val_loss: 3.6054
# Epoch 3/10
# S:\itzka\anaconda3\Lib\contextlib.py:158: UserWarning: Your input ran out of data; interrupting training. Make sure that your dataset or generator can generate at least `steps_per_epoch * epochs` batches. You may need to use the `.repeat()` function when building your dataset.
#   self.gen.throw(value)
# 438/438 ━━━━━━━━━━━━━━━━━━━━ 42s 96ms/step - accuracy: 0.0685 - loss: 3.4865 - val_accuracy: 0.0782 - val_loss: 3.3941
# Epoch 4/10
# 438/438 ━━━━━━━━━━━━━━━━━━━━ 0s 136us/step - accuracy: 0.1000 - loss: 3.1857 - val_accuracy: 0.0769 - val_loss: 3.3999
# Epoch 5/10
# 438/438 ━━━━━━━━━━━━━━━━━━━━ 43s 98ms/step - accuracy: 0.0937 - loss: 3.3394 - val_accuracy: 0.0818 - val_loss: 3.3646
# Epoch 6/10
# 438/438 ━━━━━━━━━━━━━━━━━━━━ 0s 93us/step - accuracy: 0.1500 - loss: 3.2739 - val_accuracy: 0.1538 - val_loss: 2.8476
# Epoch 7/10
# 438/438 ━━━━━━━━━━━━━━━━━━━━ 43s 97ms/step - accuracy: 0.1283 - loss: 3.1693 - val_accuracy: 0.0914 - val_loss: 3.3559
# Epoch 8/10
# 438/438 ━━━━━━━━━━━━━━━━━━━━ 0s 125us/step - accuracy: 0.1000 - loss: 3.1992 - val_accuracy: 0.0000e+00 - val_loss: 3.5174
# Epoch 9/10
# 438/438 ━━━━━━━━━━━━━━━━━━━━ 44s 101ms/step - accuracy: 0.1815 - loss: 2.8957 - val_accuracy: 0.1164 - val_loss: 3.3398
# Epoch 10/10
# 438/438 ━━━━━━━━━━━━━━━━━━━━ 0s 133us/step - accuracy: 0.2500 - loss: 2.5171 - val_accuracy: 0.2308 - val_loss: 3.3214
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# Model saved to F:/Projects/AI/Electro AI/Datasets/archive/images\model.h5

# %%
import tensorflow as tf

# Path to the saved model
dataset_dir = 'F:/Projects/AI/Electro AI/Datasets/archive/images'
model_path = os.path.join(dataset_dir, 'model.h5')
model = tf.keras.models.load_model(model_path)
print(f"Model loaded from {model_path}")
# Out:
# WARNING:absl:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Model loaded from F:/Projects/AI/Electro AI/Datasets/archive/images\model.h5

# %%
from tensorflow.keras.preprocessing import image
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
import tensorflow as tf
import os

# Load the saved model
dataset_dir = 'F:/Projects/AI/Electro AI/Datasets/archive/images'
model_path = os.path.join(dataset_dir, 'model.h5')
model = tf.keras.models.load_model(model_path)

# Function to preprocess image
def preprocess_image(img_path, target_size):
    if not os.path.isfile(img_path):
        raise FileNotFoundError(f"The image file does not exist: {img_path}")
        
    img = image.load_img(img_path, target_size=target_size)
    img_array = image.img_to_array(img)
    img_array = np.expand_dims(img_array, axis=0)  # Add batch dimension
    img_array = img_array / 255.0  # Scale pixel values to [0, 1]
    return img_array

# Load class names (should match the order used during training)
class_names = sorted(os.listdir(os.path.join(dataset_dir, 'train')))

# Path to the new image
img_path = 'F:/Projects/AI/Electro AI/new/capacitors.jpg'  # Update this path to your new image
target_size = (150, 150)  # Replace with the size used during training

# Print the path to verify
print(f"Image path: {img_path}")

# Preprocess the image
preprocessed_image = preprocess_image(img_path, target_size)

# Make a prediction
predictions = model.predict(preprocessed_image)
predicted_class = np.argmax(predictions, axis=1)
predicted_label = class_names[predicted_class[0]]

# Display the result
print(f"Predicted class: {predicted_label}")

# Display and save the image
img = mpimg.imread(img_path)
plt.imshow(img)
plt.title(f"Predicted class: {predicted_label}")
plt.axis('off')

# Save the image with a new name indicating the predicted class
save_path = os.path.join(os.path.dirname(img_path), f"{predicted_label}_{os.path.basename(img_path)}")
plt.savefig(save_path, bbox_inches='tight', pad_inches=0)
print(f"Saved the image with prediction to {save_path}")

plt.show()
# Out:
# WARNING:absl:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Image path: F:/Projects/AI/Electro AI/new/capacitors.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 104ms/step
# Predicted class: electric-relay
# Saved the image with prediction to F:/Projects/AI/Electro AI/new\electric-relay_capacitors.jpg

# %%
import tensorflow as tf
from tensorflow.keras.preprocessing import image
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
import os
from tkinter import Tk
from tkinter.filedialog import askopenfilename

# Paths
dataset_dir = 'F:/Projects/AI/Electro AI/Datasets/archive/images'
model_path = os.path.join(dataset_dir, 'model.h5')

# Load the saved model
model = tf.keras.models.load_model(model_path)

# Function to preprocess the image
def preprocess_image(img_path, target_size):
    if not os.path.isfile(img_path):
        raise FileNotFoundError(f"The image file does not exist: {img_path}")
        
    img = image.load_img(img_path, target_size=target_size)
    img_array = image.img_to_array(img)
    img_array = np.expand_dims(img_array, axis=0)  # Add batch dimension
    img_array = img_array / 255.0  # Scale pixel values to [0, 1]
    return img_array

# Load class names (should match the order used during training)
train_dir = os.path.join(dataset_dir, 'train')
class_names = sorted(os.listdir(train_dir))

# Create a Tkinter root window (it will not be shown)
root = Tk()
root.withdraw()  # Hide the root window

# Open file dialog to select an image file
img_path = askopenfilename(
    title="Select an Image File",
    filetypes=[("Image Files", "*.jpg;*.jpeg;*.png;*.bmp;*.gif")]
)

if not img_path:
    print("No file selected.")
else:
    target_size = (150, 150)  # Replace with the size used during training

    # Print the path to verify
    print(f"Image path: {img_path}")

    try:
        # Preprocess the image
        preprocessed_image = preprocess_image(img_path, target_size)

        # Make a prediction
        predictions = model.predict(preprocessed_image)
        predicted_class = np.argmax(predictions, axis=1)
        predicted_label = class_names[predicted_class[0]]

        # Display the result
        print(f"Predicted class: {predicted_label}")

        # Display and save the image
        img = mpimg.imread(img_path)
        plt.imshow(img)
        plt.title(f"Predicted class: {predicted_label}")
        plt.axis('off')

        # Save the image with a new name indicating the predicted class
        save_path = os.path.join(os.path.dirname(img_path), f"{predicted_label}_{os.path.basename(img_path)}")
        plt.savefig(save_path, bbox_inches='tight', pad_inches=0)
        print(f"Saved the image with prediction to {save_path}")

        plt.show()

    except FileNotFoundError as e:
        print(e)
    except Exception as e:
        print(f"An error occurred: {e}")
# Out:
# WARNING:absl:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# No file selected.
